# %% [markdown]
# # Analysis of car volume data from the CBS

# %%
import pandas as pd
from siuba import *
import plotly.express as px

# %%
df = pd.read_excel("../data/car_volume/t01.xlsx")

# %%
df
# Out:
#      לוח 1. נפח תנועה לפי דרך, קטע, היום בשבוע ונפח תנועה מרבי Unnamed: 1  \
# 0     (הנתונים בלוח הם לפי יר"מ, מלבד קטעי הדרך המפו...               NaN
# 1                                                   NaN               NaN
# 2                                         אורך קטע בק"מ               שנה
# 3                                                   NaN               NaN
# 4                                                   NaN               NaN
# ...                                                 ...               ...
# 9872                                                  4              2017
# 9873                                                NaN               NaN
# 9874   דרך 9977   קטע 10    מק"מ 76.3   עד ק"מ 81.5 ...               NaN
# 9875                                                NaN               NaN
# 9876                                                5.2              2015
#
#      Unnamed: 2 Unnamed: 3          Unnamed: 4             Unnamed: 5  \
# ...
